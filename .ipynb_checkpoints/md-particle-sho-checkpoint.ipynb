# %%
import numpy as np

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
r = -1.0 #m
v = 0.0 #m/s
a = 0.0 #m/s2
t= 0.0 #s
i = 0
dt = 0.00001 #s

k = 400 #N/m
m = 0.01 #Kg

# %%
pList = []
timeIndex = []
for i in range(100000):
    r = r + v * dt + (1/2) * dt**2
    v = v + a * dt
    a = - k*r/m
    pList.append(r)
    timeIndex.append(i*dt)

# %%
pos = pd.Series(pList, index=timeIndex)

# %%
pos.plot()
